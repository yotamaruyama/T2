# %%
import pandas as pd
from sklearn.utils.testing import all_estimators
from sklearn.model_selection import KFold
import warnings
from sklearn.model_selection import cross_val_score

# アヤメデータの読み込み
iris_data = pd.read_csv("iris.csv", encoding="utf-8")

# アヤメデータをラベルと入力データに分離する 
y = iris_data.loc[:,"Name"]
x = iris_data.loc[:,["SepalLength","SepalWidth","PetalLength","PetalWidth"]]

# classifierのアルゴリズム全てを取得する 
allAlgorithms = all_estimators(type_filter="classifier")

# K分割クロスバリデーション用オブジェクト --- (※1)
kfold_cv = KFold(n_splits=5, shuffle=True)
warnings.filterwarnings('ignore')

for(name, algorithm) in allAlgorithms :
  try :
    # 各アリゴリズムのオブジェクトを作成
    if(name == "LinearSVC") :
      clf = algorithm(max_iter = 10000)
    else:
      clf = algorithm()

    # scoreメソッドをもつクラスを対象とする--- (※2)
    if hasattr(clf,"score"):
        # クロスバリデーションを行う--- (※3)
        scores = cross_val_score(clf, x, y, cv=kfold_cv)
        print(name,"の正解率=")
        print(scores)
  
  # Exceptionは無視する
  except Exception as e :
    pass
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\linear_assignment_.py:21: DeprecationWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# AdaBoostClassifier の正解率=
# [0.93333333 0.96666667 0.93333333 0.96666667 0.96666667]
# BaggingClassifier の正解率=
# [0.93333333 0.9        1.         0.93333333 1.        ]
# BernoulliNB の正解率=
# [0.33333333 0.26666667 0.3        0.23333333 0.26666667]
# CalibratedClassifierCV の正解率=
# [0.9        0.93333333 1.         0.9        0.9       ]
# ComplementNB の正解率=
# [0.7        0.76666667 0.66666667 0.66666667 0.53333333]
# DecisionTreeClassifier の正解率=
# [0.93333333 0.96666667 1.         0.86666667 0.93333333]
# DummyClassifier の正解率=
# [0.16666667 0.23333333 0.23333333 0.26666667 0.16666667]
# ExtraTreeClassifier の正解率=
# [0.96666667 1.         0.83333333 1.         0.8       ]
# ExtraTreesClassifier の正解率=
# [0.96666667 0.9        0.93333333 1.         1.        ]
# GaussianNB の正解率=
# [0.93333333 0.96666667 1.         0.9        1.        ]
# GaussianProcessClassifier の正解率=
# [0.96666667 0.9        0.96666667 0.93333333 0.96666667]
# GradientBoostingClassifier の正解率=
# [0.96666667 0.96666667 0.96666667 0.93333333 0.93333333]
# HistGradientBoostingClassifier の正解率=
# [0.83333333 0.96666667 0.96666667 0.93333333 1.        ]
# KNeighborsClassifier の正解率=
# [1.         0.9        0.96666667 0.96666667 1.        ]
# LabelPropagation の正解率=
# [1.         0.96666667 0.93333333 0.9        1.        ]
# LabelSpreading の正解率=
# [0.96666667 0.96666667 0.93333333 0.96666667 0.96666667]
# LinearDiscriminantAnalysis の正解率=
# [1.         1.         0.93333333 0.96666667 1.        ]
# LinearSVC の正解率=
# [1.         0.96666667 0.86666667 1.         0.93333333]
# LogisticRegression の正解率=
# [0.96666667 0.93333333 0.86666667 1.         0.93333333]
# LogisticRegressionCV の正解率=
# [0.96666667 0.96666667 0.93333333 0.76666667 0.96666667]
# MLPClassifier の正解率=
# [1.         1.         0.93333333 1.         0.93333333]
# MultinomialNB の正解率=
# [0.93333333 0.9        0.93333333 0.8        0.93333333]
# NearestCentroid の正解率=
# [0.96666667 0.93333333 0.93333333 0.9        0.9       ]
# NuSVC の正解率=
# [0.96666667 0.96666667 0.96666667 0.96666667 0.93333333]
# PassiveAggressiveClassifier の正解率=
# [0.83333333 0.83333333 0.93333333 0.73333333 0.73333333]
# Perceptron の正解率=
# [0.83333333 0.63333333 0.83333333 0.86666667 0.8       ]
# QuadraticDiscriminantAnalysis の正解率=
# [1.         0.96666667 0.96666667 0.96666667 0.93333333]
# RadiusNeighborsClassifier の正解率=
# [0.96666667 0.96666667 0.83333333 0.96666667 0.96666667]
# RandomForestClassifier の正解率=
# [0.96666667 1.         0.96666667 0.9        0.93333333]
# RidgeClassifier の正解率=
# [0.86666667 0.7        0.86666667 0.8        0.8       ]
# RidgeClassifierCV の正解率=
# [0.83333333 0.83333333 0.9        0.76666667 0.8       ]
# SGDClassifier の正解率=
# [0.9        0.9        0.93333333 0.93333333 0.83333333]
# SVC の正解率=
# [1.         0.93333333 0.9        1.         0.96666667]
